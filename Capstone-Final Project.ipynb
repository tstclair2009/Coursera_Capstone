# %% [markdown]
# # Exploring Austin, Tx

# %% [markdown]
# ### Table of Contents

# %% [markdown]
# # Introduction

# %% [markdown]
# The Goal of this Project is to identify venues in Austin Texas. In this project we will identify venues using the Foursquare API to help myself
# identify areas that I might be interested in Visiting if I choose to relocate.
#
# These locations will be judged based on ratings across all venues and average prices.

# %% [markdown]
# # Data

# %% [markdown]
# To begin with, we will take a look at Austin on the Map using the folium library.
#
# We will use the Foursquare API to fetch venues in Austin with a 100 Kilometer Radius around the city center.
